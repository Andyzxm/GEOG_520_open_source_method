# %% [markdown]
# <a href="https://colab.research.google.com/github/Andyzxm/GEOG_520_open_source_method/blob/main/A6_Xinming_Zhang_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

#Task 1 What county has the highest recorded mean elevation?
USC=pd.read_csv("/content/drive/MyDrive/GEOG520_python_data/datasets/datasets/us_county_data.csv")
USC[USC.dem == USC.dem.max()]
# Out:
#                 NAME STATE_NAME STATE_ABBR  STATE_FIPS  COUNTY_FIP  FIPS  \
# 271  San Juan County   Colorado         CO           8         111  8111
#
#      POPULATION  POP_SQMI   SQMI SUB_REGION  ...    per_for   per_dev  \
# 271         705       1.8  388.3        Mtn  ...  41.437978  0.698639
#
#       per_wet  per_crop  per_past_grass  strm_length  strm_den  per_karst  \
# 271  3.192662       0.0       34.556109          0.0       0.0   1.681503
#
#      rail_den  road_den
# 271  0.037236  0.445666
#
# [1 rows x 37 columns]

# %%
#Task 2 : What state has the lowest mean county elevation? 
USC[USC.dem== USC.dem.min()]
# Out:
#                     NAME STATE_NAME STATE_ABBR  STATE_FIPS  COUNTY_FIP   FIPS  \
# 1116  Plaquemines Parish  Louisiana         LA          22          75  22075
#
#       POPULATION  POP_SQMI     SQMI SUB_REGION  ...  per_for   per_dev  \
# 1116       23515      22.6  1041.63    W S Cen  ...  0.37337  2.963142
#
#         per_wet  per_crop  per_past_grass  strm_length  strm_den  per_karst  \
# 1116  104.01173  0.080966        2.169764   139.611809   0.05175        0.0
#
#       rail_den  road_den
# 1116  0.024627  0.842096
#
# [1 rows x 37 columns]

# %%
#Task 3 : How many counties have a mean elevation greater than 1,000 meters?
USC.query('dem > 1000')
print(len(USC.query('dem > 1000')))
# Out:
# 343

# %%
#Task 4  How many counties have a mean elevation greater than 1,000 meters and a percent forest cover greater than 40%? 
USC.query('dem> 1000 and per_for>40')
print(len(USC.query('dem> 1000 and per_for>40')))
# Out:
# 80

# %%
#Task 5 : How many counties have a mean elevation lower than 100 meters and a percent developed larger than 35%?
USC.query('dem<100 and per_dev>35')
print(len(USC.query('dem<100 and per_dev>35')))
# Out:
# 68

# %%
#Task 6 : Which subregion of the country has the largest number of counties?
USC.groupby('SUB_REGION')["NAME"].count()
# Out:
# SUB_REGION
# E N Cen    437
# E S Cen    364
# Mid Atl    150
# Mtn        281
# N Eng       67
# Pacific    133
# S Atl      584
# W N Cen    618
# W S Cen    470
# Name: NAME, dtype: int64

# %%
#Task 7 which subregion of the country has the highest average county mean annual temperature?
USC.groupby('SUB_REGION')["tempmn"].max()
# Out:
# SUB_REGION
# E N Cen    14.341190
# E S Cen    19.679878
# Mid Atl    13.314737
# Mtn        22.593860
# N Eng      11.285000
# Pacific    22.804279
# S Atl      24.845762
# W N Cen    15.518313
# W S Cen    23.763271
# Name: tempmn, dtype: float64

# %%
#Task 8 Does Nebraska or Kansas have the highest average county percent cropland
NK= USC.query('STATE_NAME == "Nebraska" or STATE_NAME == "Kansas"')

NK.groupby("STATE_NAME")["per_crop"].mean()
# Out:
# STATE_NAME
# Kansas      44.280108
# Nebraska    48.596657
# Name: per_crop, dtype: float64

# %%
#Task 9 How many counties have a percent cropland greater than 25%, a mean temperature higher than 10°Celsius, and are not in the West South Central subregion?
USC.query('per_corp>25 and tempmn>10 and SUB_REGION!="W S Cen"')
print(len(USC.query('per_corp>25 and tempmn>10 and SUB_REGION!="W S Cen"')))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     199             if self.has_resolvers:
# --> 200                 return self.resolvers[key]
#     201
#
# /usr/lib/python3.7/collections/__init__.py in __getitem__(self, key)
#     915                 pass
# --> 916         return self.__missing__(key)            # support subclasses that define __missing__
#     917
#
# /usr/lib/python3.7/collections/__init__.py in __missing__(self, key)
#     907     def __missing__(self, key):
# --> 908         raise KeyError(key)
#     909
#
# KeyError: 'per_corp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#Task 10 Which county in the country has the highest percent cropland? 
USC[USC.per_crop == USC.per_crop.max()]
# Out:
#               NAME STATE_NAME STATE_ABBR  STATE_FIPS  COUNTY_FIP   FIPS  \
# 666  Benton County    Indiana         IN          18           7  18007
#
#      POPULATION  POP_SQMI    SQMI SUB_REGION  ...   per_for   per_dev  \
# 666        8719      21.4  406.51    E N Cen  ...  0.837892  5.177973
#
#       per_wet   per_crop  per_past_grass  strm_length  strm_den  per_karst  \
# 666  0.266887  92.522482        1.113913          0.0       0.0     0.2849
#
#      rail_den  road_den
# 666  0.163555  2.484602
#
# [1 rows x 37 columns]

# %%
#Task 11 Which county in the country has the highest percent developed land?
USC[USC.per_dev == USC.per_dev.max()]
# Out:
#                  NAME STATE_NAME STATE_ABBR  STATE_FIPS  COUNTY_FIP   FIPS  \
# 1824  New York County   New York         NY          36          61  36061
#
#       POPULATION  POP_SQMI   SQMI SUB_REGION  ...   per_for    per_dev  \
# 1824     1694251   74146.7  22.85    Mid Atl  ...  2.019127  96.095544
#
#        per_wet  per_crop  per_past_grass  strm_length  strm_den  per_karst  \
# 1824  0.211693       0.0        0.256952          0.0       0.0        0.0
#
#       rail_den   road_den
# 1824  0.905958  10.987467
#
# [1 rows x 37 columns]

# %%
#Task 12 : Which subregion has the highest total population?

USC.groupby('SUB_REGION')["POPULATION"].sum()
# Out:
# SUB_REGION
# E N Cen    47368533
# E S Cen    19402234
# Mid Atl    42492943
# Mtn        24919150
# N Eng      15116205
# Pacific    51480760
# S Atl      66026391
# W N Cen    21616921
# W S Cen    40774139
# Name: POPULATION, dtype: int64

# %%
#Task 13 : Which state has a higher percent of households with internet access (all internet access, not just broadband), West Virginia or North Dakota?
WVvND = USC.query('STATE_NAME == "West Virginia" or STATE_NAME == "North Dakota"')
WVvND.groupby("STATE_NAME")["per_broadband" and "per_internet"].max()
# Out:
# STATE_NAME
# North Dakota     89.581096
# West Virginia    90.017655
# Name: per_internet, dtype: float64

# %%
#Task 14:  Of all the counties with a mean elevation greater than 1,200 meters, which has the highest total annual precipitation?
USC1200= USC.query('dem > 1200')
USC1200[USC1200.precip == USC1200.precip.max()]
# Out:
#               NAME  STATE_NAME STATE_ABBR  STATE_FIPS  COUNTY_FIP  FIPS  \
# 185  Nevada County  California         CA           6          57  6057
#
#      POPULATION  POP_SQMI   SQMI SUB_REGION  ...    per_for   per_dev  \
# 185      102241     105.0  973.8    Pacific  ...  68.647252  6.557344
#
#       per_wet  per_crop  per_past_grass  strm_length  strm_den  per_karst  \
# 185  0.316009       0.0        3.515759    34.073311   0.01351        0.0
#
#      rail_den  road_den
# 185  0.040003   3.07485
#
# [1 rows x 37 columns]

# %%
# Task 15 What county has the largest difference between its annual lowest and highest temperatures?
USC["rad_dif"]=USC["tempmax"]-USC["tempmin"]
USC[USC.rad_dif == USC.rad_dif.max()  ]
# Out:
#                NAME STATE_NAME STATE_ABBR  STATE_FIPS  COUNTY_FIP  FIPS  \
# 216  Alamosa County   Colorado         CO           8           3  8003
#
#      POPULATION  POP_SQMI    SQMI SUB_REGION  ...   per_dev   per_wet  \
# 216       16376      22.6  723.29        Mtn  ...  3.065698  9.912224
#
#       per_crop  per_past_grass  strm_length  strm_den  per_karst  rail_den  \
# 216  16.171747        6.571714    38.975651  0.020806        0.0  0.051726
#
#      road_den    rad_dif
# 216  1.282193  18.540182
#
# [1 rows x 38 columns]
